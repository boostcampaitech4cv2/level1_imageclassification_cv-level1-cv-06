# %% [markdown]
# ## Easy Experiment .ipynb File

# %% [markdown]
# # train

# %% [markdown]
# ## import

# %%
import torch
import torch.nn as nn
from torch.optim import *
from torch.optim.lr_scheduler import *
import torch.nn.functional as F

import random

import itertools

import numpy as np

import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn.metrics import f1_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

import multiprocessing
import timm

from PIL import Image

import os
import json

import pandas as pd
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

from sklearn.model_selection import train_test_split

# %%
with torch.no_grad():
    torch.cuda.empty_cache()

# %%
def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

# %% [markdown]
# ## configuration

# %%
### cofiguration
seed = 42
check_point_dir_name = 'age_regression_resnet'

data_dir = './dataset/train/images/'
train_csv_path = './dataset/train/custom_train.csv'
save_dir = f'./checkpoints/{check_point_dir_name}'

train_b_size = 32
valid_b_size = 100
epochs = 25
print_interval = 100
lr = 1e-4
model_name = 'resnet34'
num_labels = 1
loss_function_name = 'MSELoss' # ex FocalLoss, CrossEntropyLoss
optimizer_name = 'AdamW'
comment = 'For age Regression by efficient_b4'


use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")


seed_everything(seed)

# %%
train_df = pd.read_csv(train_csv_path)
imgs_path = train_df['path'] 
labels = train_df['age'] # input your label feature
stratify_col = train_df['class']

train_paths, valid_paths, train_labels, valid_labels = train_test_split(imgs_path, labels,
                                                                        train_size=0.7,
                                                                        shuffle=True,
                                                                        random_state=seed,
                                                                        stratify=stratify_col)

# %%
os.makedirs(save_dir,exist_ok=True)

# %%
dict_args = {
'seed' : seed,
'train_b_size': train_b_size,
'epochs' : epochs,
'lr' : 1e-4,
'model_name' : model_name,
'num_labels' : num_labels,
'loss_function_name' : loss_function_name,
'optimizer_name' : optimizer_name,
'comment' : comment
}

# %%
with open(os.path.join(save_dir, 'config.json'), 'w', encoding='utf-8') as f:
        json.dump(dict_args, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## datasets class

# %%
class CustomTrainDataset(Dataset):
    ## input pd.Series
    ## output np.ndarray
    ## change dummy, if label_col is 'gender' or 'mask_state'
    def __init__(self, img_paths : pd.Series, labels : pd.Series, label_col='class', transforms=None):
        self.img_paths = img_paths.to_numpy()
        self.transforms = transforms
        if label_col == 'gender':
            self.labels = pd.get_dummies(labels).to_numpy()
        elif label_col == 'mask_state':
            self.labels = pd.get_dummies(labels).to_numpy()
        else: # age, classes
            self.labels = labels.to_numpy()
        ## if (False), assert occur
        assert self.transforms is not None, 'you must use transforms in Trainset'
    
    ## return numpy img, label
    def __getitem__(self, index):
        img_path = self.img_paths[index]
        img = np.array(Image.open(img_path))

        img = self.transforms(image=img)["image"]
        label = self.labels[index]
        return img, label

    def __len__(self):
        return len(self.labels)

# %% [markdown]
# ## augmentations

# %%
train_transforms = A.Compose([A.Resize(height=224, width=224),
                              A.HorizontalFlip(p=0.5),
                              A.RandomBrightnessContrast(p=0.5),
                              A.GaussianBlur(p=0.5),
                              A.GridDistortion(p=0.5),
                              A.Rotate(limit=30, p=0.5),
                              A.Normalize(mean=(0.56019358,0.52410121,0.501457),
                              std=(0.23318603,0.24300033,0.24567522)),
                              ToTensorV2()])

valid_transforms = A.Compose([A.Resize(height=224, width=224),
                              A.Normalize(mean=(0.56019358,0.52410121,0.501457),
                              std=(0.23318603,0.24300033,0.24567522)),
                              ToTensorV2()])

# %% [markdown]
# ## make dataset and dataloader

# %%
train_dset = CustomTrainDataset(train_paths, train_labels, 'age', train_transforms)
val_dset = CustomTrainDataset(valid_paths, valid_labels, 'age', valid_transforms)

# %%
train_loader = DataLoader(
        train_dset,
        batch_size=train_b_size,
        num_workers=multiprocessing.cpu_count() // 2,
        shuffle=True,
        pin_memory=use_cuda,
        drop_last=False,
    )

val_loader = DataLoader(
        val_dset,
        batch_size=valid_b_size,
        num_workers=multiprocessing.cpu_count() // 2,
        shuffle=False,
        pin_memory=use_cuda,
        drop_last=True,
    )

# %% [markdown]
# ## visualization transform

# %%
## for check transform
imgs, labels = next(iter(train_loader))
plt.imshow(make_grid(imgs, normalize=True).permute(1,2,0))
plt.show()

# %% [markdown]
# ## Model

# %%
model = timm.create_model(model_name=model_name, pretrained=True, num_classes=num_labels)
model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act1): ReLU(inplace=True)
#       (aa): Identity()
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act2): ReLU(inplace=True)
#     )
#   )
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (fc): Linear(in_features=512, out_features=1, bias=True)
# )

# %%
model = torch.nn.DataParallel(model)

# %%
model
# Out:
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act1): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#     )
#     (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (fc): Linear(in_features=512, out_features=1, bias=True)
#   )
# )

# %%
# model(torch.Tensor(2,3,224,224).to(device)).size()

# %%
# b_labels.size()

# %% [markdown]
# ## Loss function

# %%
class FocalLoss(nn.Module):
    def __init__(self, weight=None,
                 gamma=2., reduction='mean'):
        nn.Module.__init__(self)
        self.weight = weight
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, input_tensor, target_tensor):
        log_prob = F.log_softmax(input_tensor, dim=-1)
        prob = torch.exp(log_prob)
        return F.nll_loss(
            ((1 - prob) ** self.gamma) * log_prob,
            target_tensor,
            weight=self.weight,
            reduction=self.reduction
        )

# %%
if loss_function_name == 'CrossEntropyLoss':
    criterion = nn.CrossEntropyLoss()
elif loss_function_name == 'FocalLoss':
    criterion = FocalLoss()
elif loss_function_name == 'MSELoss':
    criterion = nn.MSELoss()
else:
    raise ValueError(f'not implement Loss function : {loss_function_name}')

# %%
criterion
# Out:
# MSELoss()

# %% [markdown]
# ## Optimizer

# %%
# if you param freeze, not update during training
optimizer = None
if optimizer_name == 'AdamW':
    optimizer = AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=lr) 
else:
    raise ValueError(f'not implement Optimizer : {optimizer_name}')

# %%
optimizer
# Out:
# AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0.01
# )

# %%
imgs, labels = next(iter(train_loader))
labels.unsqueeze(dim=1).size()
labels.size()
# Out:
# torch.Size([32])

# %% [markdown]
# ## Train

# %%
best_val_loss = np.Inf
best_val_MAE = np.Inf

for epoch in range(epochs):
    model.train()

    epoch_loss = 0
    epoch_preds = []
    epoch_labels = []

    iter_preds = []
    iter_labels = []

    for idx, train_batch in enumerate(train_loader):
        b_imgs, b_labels = train_batch # batch imgs and batch labels
        b_imgs = b_imgs.to(device)
        b_labels = b_labels.to(device)
        b_labels = b_labels.unsqueeze(dim=1)

        b_regressioned = model(b_imgs)

        # print(b_regressioned.size()) # 18
        # print(b_labels.size()) # 1

        b_loss = criterion(b_regressioned.to(torch.float32), b_labels.to(torch.float32)) ## 요거 정리

        optimizer.zero_grad()
        b_loss.backward()
        optimizer.step()

        epoch_loss+=b_loss.item()
        iter_preds+=b_regressioned.detach().cpu().numpy().flatten().tolist() # for 1d dim
        iter_labels+=b_labels.detach().cpu().numpy().flatten().tolist() # for 1d dim

        epoch_preds+=iter_preds
        epoch_labels+=iter_labels

        iter_preds = []
        iter_labels = []

        # print interval batch
        if(idx+1) % print_interval == 0:
            current_loss = epoch_loss / (idx+1) # /batch
            correct_list = [abs(i-j) for i,j in zip(epoch_preds, epoch_labels)]
            current_MAE = sum(correct_list)/len(correct_list)
            print(
                    f"Epoch[{epoch+1}/{epochs}]({idx + 1}/{len(train_loader)}) || "
                    f"training loss(MSE) {current_loss:2.4f} || training MAE {current_MAE:2.4f} || lr {lr}"
                )

    with torch.no_grad():
        print("Calculating validation results...")
        model.eval()

        val_loss = []
        val_preds = [] # every data's preds
        val_labels = [] # every data's label

        for idx, val_batch in enumerate(val_loader):
            imgs, labels = val_batch
            imgs = imgs.to(device)
            labels = labels.to(device)
            labels = labels.unsqueeze(dim=1)
            b_preds = model(imgs)
            b_loss = criterion(b_preds, labels).item()
            val_loss.append(b_loss)

            val_preds += b_preds.detach().cpu().numpy().flatten().tolist()
            val_labels += labels.detach().cpu().numpy().flatten().tolist()

        epoch_val_MAE = mean_absolute_error(val_labels, val_preds)
        epoch_val_MSE =  mean_squared_error(val_labels, val_preds)
        best_val_MSE = min(best_val_loss, epoch_val_MSE)

        if epoch_val_MAE < best_val_MAE:
                print(f"New best model for val MAE : {epoch_val_MAE:2.4f}! saving the best model..")
                best_val_MAE = epoch_val_MAE
                torch.save(model.module.state_dict(), f"{save_dir}/best.pth")
        torch.save(model.module.state_dict(), f'{save_dir}/last.pth')
        print(
                f"[Val] MAE : {epoch_val_MAE:2.4f}, loss(MSE): {epoch_val_MSE:2.4f} || "
                f"best MAE : {best_val_MAE:2.4f}, best loss(MSE): {best_val_MSE:2.4f}"
            )
# Out:
# Epoch[1/25](100/414) || training loss(MSE) 885.3648 || training MAE 27.1702 || lr 0.0001
# Epoch[1/25](200/414) || training loss(MSE) 603.1721 || training MAE 21.8554 || lr 0.0001
# Epoch[1/25](300/414) || training loss(MSE) 454.4534 || training MAE 18.2645 || lr 0.0001
# Epoch[1/25](400/414) || training loss(MSE) 357.3260 || training MAE 15.3494 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 5.7946! saving the best model..
# [Val] MAE : 5.7946, loss(MSE): 44.8978 || best MAE : 5.7946, best loss(MSE): 44.8978
# Epoch[2/25](100/414) || training loss(MSE) 35.5433 || training MAE 4.4543 || lr 0.0001
# Epoch[2/25](200/414) || training loss(MSE) 32.8808 || training MAE 4.2106 || lr 0.0001
# Epoch[2/25](300/414) || training loss(MSE) 30.9687 || training MAE 4.0440 || lr 0.0001
# Epoch[2/25](400/414) || training loss(MSE) 29.6489 || training MAE 3.9513 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 4.3513! saving the best model..
# [Val] MAE : 4.3513, loss(MSE): 32.1368 || best MAE : 4.3513, best loss(MSE): 32.1368
# Epoch[3/25](100/414) || training loss(MSE) 21.5336 || training MAE 3.3724 || lr 0.0001
# Epoch[3/25](200/414) || training loss(MSE) 21.7958 || training MAE 3.3557 || lr 0.0001
# Epoch[3/25](300/414) || training loss(MSE) 21.0684 || training MAE 3.2906 || lr 0.0001
# Epoch[3/25](400/414) || training loss(MSE) 20.8108 || training MAE 3.2521 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 5.1916, loss(MSE): 43.9760 || best MAE : 4.3513, best loss(MSE): 43.9760
# Epoch[4/25](100/414) || training loss(MSE) 16.9503 || training MAE 2.8956 || lr 0.0001
# Epoch[4/25](200/414) || training loss(MSE) 15.8016 || training MAE 2.8006 || lr 0.0001
# Epoch[4/25](300/414) || training loss(MSE) 14.8852 || training MAE 2.7061 || lr 0.0001
# Epoch[4/25](400/414) || training loss(MSE) 14.7074 || training MAE 2.6945 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 2.5890! saving the best model..
# [Val] MAE : 2.5890, loss(MSE): 14.9502 || best MAE : 2.5890, best loss(MSE): 14.9502
# Epoch[5/25](100/414) || training loss(MSE) 12.2320 || training MAE 2.5074 || lr 0.0001
# Epoch[5/25](200/414) || training loss(MSE) 13.0348 || training MAE 2.5622 || lr 0.0001
# Epoch[5/25](300/414) || training loss(MSE) 13.1016 || training MAE 2.5506 || lr 0.0001
# Epoch[5/25](400/414) || training loss(MSE) 13.0745 || training MAE 2.5355 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 2.0715! saving the best model..
# [Val] MAE : 2.0715, loss(MSE): 9.1862 || best MAE : 2.0715, best loss(MSE): 9.1862
# Epoch[6/25](100/414) || training loss(MSE) 12.1411 || training MAE 2.4121 || lr 0.0001
# Epoch[6/25](200/414) || training loss(MSE) 11.7946 || training MAE 2.3754 || lr 0.0001
# Epoch[6/25](300/414) || training loss(MSE) 12.1349 || training MAE 2.4053 || lr 0.0001
# Epoch[6/25](400/414) || training loss(MSE) 12.0099 || training MAE 2.3997 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 2.3781, loss(MSE): 9.6047 || best MAE : 2.0715, best loss(MSE): 9.6047
# Epoch[7/25](100/414) || training loss(MSE) 10.0648 || training MAE 2.2552 || lr 0.0001
# Epoch[7/25](200/414) || training loss(MSE) 9.7421 || training MAE 2.2101 || lr 0.0001
# Epoch[7/25](300/414) || training loss(MSE) 9.8379 || training MAE 2.2133 || lr 0.0001
# Epoch[7/25](400/414) || training loss(MSE) 9.7245 || training MAE 2.1947 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 2.1644, loss(MSE): 8.4664 || best MAE : 2.0715, best loss(MSE): 8.4664
# Epoch[8/25](100/414) || training loss(MSE) 10.3600 || training MAE 2.2316 || lr 0.0001
# Epoch[8/25](200/414) || training loss(MSE) 9.0842 || training MAE 2.0942 || lr 0.0001
# Epoch[8/25](300/414) || training loss(MSE) 9.3229 || training MAE 2.1271 || lr 0.0001
# Epoch[8/25](400/414) || training loss(MSE) 9.4098 || training MAE 2.1357 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 2.9853, loss(MSE): 15.7229 || best MAE : 2.0715, best loss(MSE): 15.7229
# Epoch[9/25](100/414) || training loss(MSE) 8.3569 || training MAE 2.0726 || lr 0.0001
# Epoch[9/25](200/414) || training loss(MSE) 7.9860 || training MAE 2.0069 || lr 0.0001
# Epoch[9/25](300/414) || training loss(MSE) 7.8294 || training MAE 1.9975 || lr 0.0001
# Epoch[9/25](400/414) || training loss(MSE) 8.2245 || training MAE 2.0264 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 1.8591! saving the best model..
# [Val] MAE : 1.8591, loss(MSE): 6.9089 || best MAE : 1.8591, best loss(MSE): 6.9089
# Epoch[10/25](100/414) || training loss(MSE) 8.6448 || training MAE 2.0274 || lr 0.0001
# Epoch[10/25](200/414) || training loss(MSE) 8.4471 || training MAE 2.0040 || lr 0.0001
# Epoch[10/25](300/414) || training loss(MSE) 8.1439 || training MAE 1.9717 || lr 0.0001
# Epoch[10/25](400/414) || training loss(MSE) 7.8991 || training MAE 1.9446 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 1.8341! saving the best model..
# [Val] MAE : 1.8341, loss(MSE): 7.7911 || best MAE : 1.8341, best loss(MSE): 7.7911
# Epoch[11/25](100/414) || training loss(MSE) 6.6837 || training MAE 1.8065 || lr 0.0001
# Epoch[11/25](200/414) || training loss(MSE) 6.6890 || training MAE 1.8033 || lr 0.0001
# Epoch[11/25](300/414) || training loss(MSE) 7.1161 || training MAE 1.8592 || lr 0.0001
# Epoch[11/25](400/414) || training loss(MSE) 7.4495 || training MAE 1.8920 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 1.8880, loss(MSE): 6.9398 || best MAE : 1.8341, best loss(MSE): 6.9398
# Epoch[12/25](100/414) || training loss(MSE) 7.2839 || training MAE 1.8649 || lr 0.0001
# Epoch[12/25](200/414) || training loss(MSE) 7.1878 || training MAE 1.8517 || lr 0.0001
# Epoch[12/25](300/414) || training loss(MSE) 7.5058 || training MAE 1.8761 || lr 0.0001
# Epoch[12/25](400/414) || training loss(MSE) 7.2525 || training MAE 1.8611 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 1.8894, loss(MSE): 6.2436 || best MAE : 1.8341, best loss(MSE): 6.2436
# Epoch[13/25](100/414) || training loss(MSE) 7.4347 || training MAE 1.8468 || lr 0.0001
# Epoch[13/25](200/414) || training loss(MSE) 7.7995 || training MAE 1.9003 || lr 0.0001
# Epoch[13/25](300/414) || training loss(MSE) 7.2011 || training MAE 1.8451 || lr 0.0001
# Epoch[13/25](400/414) || training loss(MSE) 6.8379 || training MAE 1.7952 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 1.7829! saving the best model..
# [Val] MAE : 1.7829, loss(MSE): 6.7170 || best MAE : 1.7829, best loss(MSE): 6.7170
# Epoch[14/25](100/414) || training loss(MSE) 6.1214 || training MAE 1.6793 || lr 0.0001
# Epoch[14/25](200/414) || training loss(MSE) 6.0775 || training MAE 1.6948 || lr 0.0001
# Epoch[14/25](300/414) || training loss(MSE) 6.1631 || training MAE 1.7144 || lr 0.0001
# Epoch[14/25](400/414) || training loss(MSE) 6.2104 || training MAE 1.7246 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 1.8260, loss(MSE): 5.8980 || best MAE : 1.7829, best loss(MSE): 5.8980
# Epoch[15/25](100/414) || training loss(MSE) 5.9762 || training MAE 1.6797 || lr 0.0001
# Epoch[15/25](200/414) || training loss(MSE) 5.9123 || training MAE 1.6914 || lr 0.0001
# Epoch[15/25](300/414) || training loss(MSE) 6.0096 || training MAE 1.7065 || lr 0.0001
# Epoch[15/25](400/414) || training loss(MSE) 6.0491 || training MAE 1.7150 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 1.5745! saving the best model..
# [Val] MAE : 1.5745, loss(MSE): 4.9475 || best MAE : 1.5745, best loss(MSE): 4.9475
# Epoch[16/25](100/414) || training loss(MSE) 5.5646 || training MAE 1.6511 || lr 0.0001
# Epoch[16/25](200/414) || training loss(MSE) 5.3556 || training MAE 1.6242 || lr 0.0001
# Epoch[16/25](300/414) || training loss(MSE) 5.4315 || training MAE 1.6384 || lr 0.0001
# Epoch[16/25](400/414) || training loss(MSE) 5.3911 || training MAE 1.6307 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 1.5097! saving the best model..
# [Val] MAE : 1.5097, loss(MSE): 4.6691 || best MAE : 1.5097, best loss(MSE): 4.6691
# Epoch[17/25](100/414) || training loss(MSE) 5.4312 || training MAE 1.6645 || lr 0.0001
# Epoch[17/25](200/414) || training loss(MSE) 4.9064 || training MAE 1.5736 || lr 0.0001
# Epoch[17/25](300/414) || training loss(MSE) 4.6274 || training MAE 1.5279 || lr 0.0001
# Epoch[17/25](400/414) || training loss(MSE) 4.5482 || training MAE 1.5141 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 1.5558, loss(MSE): 4.5468 || best MAE : 1.5097, best loss(MSE): 4.5468
# Epoch[18/25](100/414) || training loss(MSE) 3.7528 || training MAE 1.3762 || lr 0.0001
# Epoch[18/25](200/414) || training loss(MSE) 4.3290 || training MAE 1.4709 || lr 0.0001
# Epoch[18/25](300/414) || training loss(MSE) 5.1682 || training MAE 1.5696 || lr 0.0001
# Epoch[18/25](400/414) || training loss(MSE) 5.6908 || training MAE 1.6353 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 1.4803! saving the best model..
# [Val] MAE : 1.4803, loss(MSE): 4.4873 || best MAE : 1.4803, best loss(MSE): 4.4873
# Epoch[19/25](100/414) || training loss(MSE) 6.0187 || training MAE 1.6187 || lr 0.0001
# Epoch[19/25](200/414) || training loss(MSE) 5.4178 || training MAE 1.5899 || lr 0.0001
# Epoch[19/25](300/414) || training loss(MSE) 5.4971 || training MAE 1.5923 || lr 0.0001
# Epoch[19/25](400/414) || training loss(MSE) 5.5361 || training MAE 1.5978 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 1.5731, loss(MSE): 4.9618 || best MAE : 1.4803, best loss(MSE): 4.9618
# Epoch[20/25](100/414) || training loss(MSE) 4.5266 || training MAE 1.5023 || lr 0.0001
# Epoch[20/25](200/414) || training loss(MSE) 5.0344 || training MAE 1.5548 || lr 0.0001
# Epoch[20/25](300/414) || training loss(MSE) 5.2219 || training MAE 1.5873 || lr 0.0001
# Epoch[20/25](400/414) || training loss(MSE) 5.1676 || training MAE 1.5720 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 1.4045! saving the best model..
# [Val] MAE : 1.4045, loss(MSE): 4.4809 || best MAE : 1.4045, best loss(MSE): 4.4809
# Epoch[21/25](100/414) || training loss(MSE) 4.2573 || training MAE 1.4295 || lr 0.0001
# Epoch[21/25](200/414) || training loss(MSE) 5.6219 || training MAE 1.5944 || lr 0.0001
# Epoch[21/25](300/414) || training loss(MSE) 5.5721 || training MAE 1.5685 || lr 0.0001
# Epoch[21/25](400/414) || training loss(MSE) 5.8764 || training MAE 1.6065 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 1.3616! saving the best model..
# [Val] MAE : 1.3616, loss(MSE): 4.0283 || best MAE : 1.3616, best loss(MSE): 4.0283
# Epoch[22/25](100/414) || training loss(MSE) 5.2371 || training MAE 1.5392 || lr 0.0001
# Epoch[22/25](200/414) || training loss(MSE) 5.0416 || training MAE 1.5421 || lr 0.0001
# Epoch[22/25](300/414) || training loss(MSE) 4.7274 || training MAE 1.4974 || lr 0.0001
# Epoch[22/25](400/414) || training loss(MSE) 4.5939 || training MAE 1.4849 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 1.3311! saving the best model..
# [Val] MAE : 1.3311, loss(MSE): 3.8062 || best MAE : 1.3311, best loss(MSE): 3.8062
# Epoch[23/25](100/414) || training loss(MSE) 5.1726 || training MAE 1.5494 || lr 0.0001
# Epoch[23/25](200/414) || training loss(MSE) 4.6617 || training MAE 1.5085 || lr 0.0001
# Epoch[23/25](300/414) || training loss(MSE) 4.2889 || training MAE 1.4500 || lr 0.0001
# Epoch[23/25](400/414) || training loss(MSE) 4.4407 || training MAE 1.4664 || lr 0.0001
# Calculating validation results...
# New best model for val MAE : 1.2977! saving the best model..
# [Val] MAE : 1.2977, loss(MSE): 3.3569 || best MAE : 1.2977, best loss(MSE): 3.3569
# Epoch[24/25](100/414) || training loss(MSE) 3.3122 || training MAE 1.2867 || lr 0.0001
# Epoch[24/25](200/414) || training loss(MSE) 3.2630 || training MAE 1.2676 || lr 0.0001
# Epoch[24/25](300/414) || training loss(MSE) 3.3255 || training MAE 1.2651 || lr 0.0001
# Epoch[24/25](400/414) || training loss(MSE) 3.2828 || training MAE 1.2596 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 1.3152, loss(MSE): 3.6210 || best MAE : 1.2977, best loss(MSE): 3.6210
# Epoch[25/25](100/414) || training loss(MSE) 3.5838 || training MAE 1.3340 || lr 0.0001
# Epoch[25/25](200/414) || training loss(MSE) 3.3372 || training MAE 1.2999 || lr 0.0001
# Epoch[25/25](300/414) || training loss(MSE) 3.2192 || training MAE 1.2768 || lr 0.0001
# Epoch[25/25](400/414) || training loss(MSE) 3.3730 || training MAE 1.2986 || lr 0.0001
# Calculating validation results...
# [Val] MAE : 1.3176, loss(MSE): 3.5775 || best MAE : 1.2977, best loss(MSE): 3.5775

# %% [markdown]
# ```
# efficientnet_b4
# [Val] MAE : 1.0296, loss(MSE): 2.3298 || best MAE : 1.0296, best loss(MSE): 2.3298
# ```

# %% [markdown]
# ```
# resnet34
# [Val] MAE : 1.3152, loss(MSE): 3.6210 || best MAE : 1.2977, best loss(MSE): 3.6210
# ```

# %%
model
# Out:
# DataParallel(
#   (module): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act1): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (drop_block): Identity()
#         (act1): ReLU(inplace=True)
#         (aa): Identity()
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): ReLU(inplace=True)
#       )
#     )
#     (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#     (fc): Linear(in_features=512, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# # inference

# %% [markdown]
# ## inference config

# %%
model_name = 'resnet34'
check_point_dir_name = 'resnet34'
save_file_path = f'./checkpoints/{check_point_dir_name}/best.pth'
test_dir = './dataset/eval/images/'
test_csv_path = './dataset/eval/info.csv'

test_b_size = 1000
num_labels = 18
sumbission_csv_name = 'result'

# %% [markdown]
# ## checkpoint model load

# %%
model = timm.create_model(model_name=model_name, pretrained=False, num_classes=num_labels)
model.to(device)
model.load_state_dict(torch.load(save_file_path))
model = torch.nn.DataParallel(model)

# %% [markdown]
# ## test dataset

# %%
class CustomTestDataset(Dataset):
    def __init__(self, img_paths:list, transforms=None):
        self.img_paths = img_paths
        self.transforms = transforms
        assert self.transforms is not None, 'you must use transforms in Testset'

    def __getitem__(self, index):
        img = Image.open(self.img_paths[index])
        img = np.array(img)
        img = self.transforms(image=img)["image"]
        return img

    def __len__(self):
        return len(self.img_paths)

# %%
test_transforms = A.Compose([A.Resize(height=224, width=224),
                                 A.Normalize(mean=(0.56019358,0.52410121,0.501457),
                                 std=(0.23318603,0.24300033,0.24567522)),
                                 ToTensorV2()])

# %%
info = pd.read_csv(test_csv_path)
test_imgs_path = [os.path.join(test_dir, img_id) for img_id in info.ImageID]

# %%
test_dset = CustomTestDataset(test_imgs_path, test_transforms)

# %%
test_loader = DataLoader(
        test_dset,
        batch_size=test_b_size,
        num_workers=multiprocessing.cpu_count() // 2,
        shuffle=False,
        pin_memory=use_cuda,
        drop_last=False,
    )

# %%
test_preds = []
with torch.no_grad():
        for idx, images in enumerate(test_loader):
            images = images.to(device)
            pred = model(images)
            pred = pred.argmax(dim=-1)
            test_preds.extend(pred.cpu().numpy().tolist())

info['ans'] = test_preds
save_path = os.path.join(save_dir, f'{sumbission_csv_name}.csv')
info.to_csv(save_path, index=False)
print(f"Inference Done! Inference result saved at {save_path}")

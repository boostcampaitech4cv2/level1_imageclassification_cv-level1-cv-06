# %% [markdown]
# ## Easy Experiment .ipynb File

# %% [markdown]
# ### <font color='red'><b> 🐬 기억합시다 :] 실험마다 인덱스 붙여서 파일 새로만들기~! <b></font>

# %% [markdown]
# ### unseen data로 validation을 측정하는 실험

# %% [markdown]
# ## import

# %%
import torch
import torch.nn as nn
from torch.optim import *
from torch.optim.lr_scheduler import *
import torch.nn.functional as F

import random
import time
from datetime import timedelta

import numpy as np

import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from pytorch_model_summary import summary

from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score

import multiprocessing
import timm

from PIL import Image

import os
import json

import pandas as pd
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

from sklearn.model_selection import train_test_split

# %%
with torch.no_grad():
    torch.cuda.empty_cache()

# %%
def seed_everything(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

# %% [markdown]
# ## configuration

# %%
### cofiguration
seed = 42
check_point_dir_name = 'baseline2'

data_dir = './dataset/train/images/'
train_csv_path = './dataset/train/custom_train.csv'
save_dir = f'./checkpoints/{check_point_dir_name}'

train_b_size = 32
valid_b_size = 300
train_ratio = 0.8
epochs = 20
print_interval = 394
lr = 3e-4
model_name = 'efficientnetv2_rw_m'
num_labels = 18
loss_function_name = 'CrossEntropyLoss' # ex FocalLoss, CrossEntropyLoss
optimizer_name = 'AdamW'
weight_decay = 0.02
scheduler_name = 'CosineAnnealingWarmRestarts'
comment = f'스케줄러 변경'


use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")


seed_everything(seed)

# %%
df_train = pd.read_csv('./dataset/train/hypothesis_train.csv')
df_valid = pd.read_csv('./dataset/train/hypothesis_valid.csv')

# %%
df_train
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 0               0             0
# 1               1             1
# 2               2             2
# 3               3             3
# 4               4             4
# ...           ...           ...
# 15116       15116         15116
# 15117       15117         15117
# 15118       15118         15118
# 15119       15119         15119
# 15120       15120         15120
#
#                                                     path  mask_class  \
# 0      /opt/ml/repo/level1_imageclassification_cv-lev...           0
# 1      /opt/ml/repo/level1_imageclassification_cv-lev...           2
# 2      /opt/ml/repo/level1_imageclassification_cv-lev...           1
# 3      /opt/ml/repo/level1_imageclassification_cv-lev...           0
# 4      /opt/ml/repo/level1_imageclassification_cv-lev...           0
# ...                                                  ...         ...
# 15116  /opt/ml/repo/level1_imageclassification_cv-lev...           0
# 15117  /opt/ml/repo/level1_imageclassification_cv-lev...           0
# 15118  /opt/ml/repo/level1_imageclassification_cv-lev...           0
# 15119  /opt/ml/repo/level1_imageclassification_cv-lev...           0
# 15120  /opt/ml/repo/level1_imageclassification_cv-lev...           0
#
#        gender_class  age  origin_label age_cls                  people
# 0                 1   45             4  middle  000001_female_Asian_45
# 1                 1   45            16  middle  000001_female_Asian_45
# 2                 1   45            10  middle  000001_female_Asian_45
# 3                 1   45             4  middle  000001_female_Asian_45
# 4                 1   45             4  middle  000001_female_Asian_45
# ...             ...  ...           ...     ...                     ...
# 15116             0   25             0  junior    005444_male_Asian_25
# 15117             0   25             0  junior    005444_male_Asian_25
# 15118             0   25             0  junior    005444_male_Asian_25
# 15119             0   25             0  junior    005444_male_Asian_25
# 15120             1   53             4  middle  005445_female_Asian_53
#
# [15121 rows x 9 columns]

# %%
os.makedirs(save_dir,exist_ok=True)

# %%
dict_args = {
'seed' : seed,
'train_b_size': train_b_size,
'epochs' : epochs,
'lr' : lr,
'model_name' : model_name,
'num_labels' : num_labels,
'train_ratio': train_ratio,
'loss_function_name' : loss_function_name,
'optimizer_name' : optimizer_name,
'weight_decay' : weight_decay,
'scheduler_name' : scheduler_name,
'comment' : comment
}

# %%
with open(os.path.join(save_dir, 'config.json'), 'w', encoding='utf-8') as f:
        json.dump(dict_args, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## datasets class

# %%
class CustomTrainDataset(Dataset):
    ## input pd.Series
    ## output np.ndarray
    ## change dummy, if label_col is 'gender' or 'mask_state'
    def __init__(self, img_paths : pd.Series, labels : pd.Series, label_col='class', transforms=None):
        self.img_paths = img_paths.to_numpy()
        self.transforms = transforms
        if label_col == 'gender':
            self.labels = pd.get_dummies(labels).to_numpy()
        elif label_col == 'mask_state':
            self.labels = pd.get_dummies(labels).to_numpy()
        else: # age, classes
            self.labels = labels.to_numpy()
        ## if (False), assert occur
        assert self.transforms is not None, 'you must use transforms in Trainset'
    
    ## return numpy img, label
    def __getitem__(self, index):
        img_path = self.img_paths[index]
        img = np.array(Image.open(img_path))

        img = self.transforms(image=img)["image"]
        label = self.labels[index]
        return img, label

    def __len__(self):
        return len(self.labels)

# %% [markdown]
# ## augmentations

# %%
train_transforms = A.Compose([
        A.CenterCrop(height=450,width=250),
        A.HorizontalFlip(p=0.5),
        A.Resize(224, 224),
        A.CLAHE(p=1.),
        A.Normalize(mean=(0.560,0.524,0.501), std=(0.233,0.243,0.246)),
        ToTensorV2()
    ])
    
valid_transforms = A.Compose([
        A.CenterCrop(height=450,width=250),
        A.Resize(224, 224),
        A.Normalize(mean=(0.560,0.524,0.501), std=(0.233,0.243,0.246)),
        ToTensorV2()
    ])

# %% [markdown]
# ## make dataset and dataloader

# %%
train_dset = CustomTrainDataset(df_train['path'], df_train['origin_label'], 'class', train_transforms)
val_dset = CustomTrainDataset(df_valid['path'], df_valid['origin_label'], 'class', valid_transforms)

# %%
num_of_class = df_train['origin_label'].value_counts().sort_index().values.tolist()

# %%
cls_prob = []
reversed_cls_prob = []

for idx, cnt in enumerate(num_of_class):
    cls_prob.append(cnt/sum(num_of_class))
    # reversed_cls_prob.append((sum(num_of_class)-cnt)/sum(num_of_class))

reversed_cls_prob = [max(cls_prob)/prob for prob in cls_prob]

# %%
for cls, prob in enumerate(cls_prob):
    print(cls,prob*100)
# Out:
# 0 9.45704649163415
# 1 12.86290589246743
# 2 2.7114608822167847
# 3 17.82289531115667
# 4 25.13722637391707
# 5 3.438925996957873
# 6 1.8914092983268305
# 7 2.5725811784934858
# 8 0.5422921764433569
# 9 3.5645790622313336
# 10 5.02612261093843
# 11 0.6877851993915747
# 12 1.8914092983268305
# 13 2.5725811784934858
# 14 0.5422921764433569
# 15 3.5645790622313336
# 16 5.02612261093843
# 17 0.6877851993915747

# %%
for idx, prob in enumerate(reversed_cls_prob):
    print(idx, prob)
# Out:
# 0 2.6580419580419585
# 1 1.954241645244216
# 2 9.270731707317074
# 3 1.4103896103896105
# 4 1.0
# 5 7.309615384615386
# 6 13.29020979020979
# 7 9.77120822622108
# 8 46.35365853658537
# 9 7.051948051948053
# 10 5.001315789473685
# 11 36.54807692307693
# 12 13.29020979020979
# 13 9.77120822622108
# 14 46.35365853658537
# 15 7.051948051948053
# 16 5.001315789473685
# 17 36.54807692307693

# %%
train_loader = DataLoader(
        train_dset,
        batch_size=train_b_size,
        num_workers=multiprocessing.cpu_count() // 2,
        shuffle=True,
        pin_memory=use_cuda,
        drop_last=False,
    )

val_loader = DataLoader(
        val_dset,
        batch_size=valid_b_size,
        num_workers=multiprocessing.cpu_count() // 2,
        shuffle=False,
        pin_memory=use_cuda,
        drop_last=False,
    )

# %%
print(len(train_loader))
print(len(val_loader))
# Out:
# 473
# 13

# %% [markdown]
# ## visualization transform

# %%
## for check transform
imgs, labels = next(iter(train_loader))
plt.figure(figsize=(10, 5))
plt.imshow(make_grid(imgs, normalize=True).permute(1,2,0))
plt.show()

# %%
imgs, labels = next(iter(val_loader))
plt.figure(figsize=(10, 5))
plt.imshow(make_grid(imgs, normalize=True).permute(1,2,0))
plt.show()

# %% [markdown]
# ## Model

# %%
model = timm.create_model(model_name=model_name, pretrained=True, num_classes=num_labels)
model.to(device)
# model = torch.nn.DataParallel(model)
# Out:
# EfficientNet(
#   (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNormAct2d(
#     32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): EdgeResidual(
#         (conv_exp): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): EdgeResidual(
#         (conv_exp): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): EdgeResidual(
#         (conv_exp): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): EdgeResidual(
#         (conv_exp): Conv2d(32, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(128, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): EdgeResidual(
#         (conv_exp): Conv2d(56, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(224, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): EdgeResidual(
#         (conv_exp): Conv2d(56, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(224, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): EdgeResidual(
#         (conv_exp): Conv2d(56, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(224, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (4): EdgeResidual(
#         (conv_exp): Conv2d(56, 224, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(224, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (2): Sequential(
#       (0): EdgeResidual(
#         (conv_exp): Conv2d(56, 224, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(224, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): EdgeResidual(
#         (conv_exp): Conv2d(80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): EdgeResidual(
#         (conv_exp): Conv2d(80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): EdgeResidual(
#         (conv_exp): Conv2d(80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (4): EdgeResidual(
#         (conv_exp): Conv2d(80, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): Identity()
#         (conv_pwl): Conv2d(320, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(80, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(320, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=320, bias=False)
#         (bn2): BatchNormAct2d(
#           320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(320, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 320, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(320, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(152, 608, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(608, 608, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=608, bias=False)
#         (bn2): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(608, 38, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(38, 608, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(608, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(152, 608, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(608, 608, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=608, bias=False)
#         (bn2): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(608, 38, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(38, 608, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(608, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(152, 608, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(608, 608, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=608, bias=False)
#         (bn2): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(608, 38, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(38, 608, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(608, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(152, 608, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(608, 608, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=608, bias=False)
#         (bn2): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(608, 38, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(38, 608, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(608, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (5): InvertedResidual(
#         (conv_pw): Conv2d(152, 608, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(608, 608, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=608, bias=False)
#         (bn2): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(608, 38, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(38, 608, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(608, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (6): InvertedResidual(
#         (conv_pw): Conv2d(152, 608, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(608, 608, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=608, bias=False)
#         (bn2): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(608, 38, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(38, 608, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(608, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (7): InvertedResidual(
#         (conv_pw): Conv2d(152, 608, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(608, 608, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=608, bias=False)
#         (bn2): BatchNormAct2d(
#           608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(608, 38, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(38, 608, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(608, 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(152, 912, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           912, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(912, 912, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=912, bias=False)
#         (bn2): BatchNormAct2d(
#           912, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(912, 38, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(38, 912, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(912, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (5): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (6): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (7): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (8): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (9): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (10): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (11): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (12): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (13): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (14): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (5): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (6): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (7): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (8): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (9): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (10): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (11): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (12): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (13): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (14): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (15): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (16): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (17): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (18): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (19): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (20): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (21): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (22): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (23): InvertedResidual(
#         (conv_pw): Conv2d(328, 1968, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1968, 1968, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1968, bias=False)
#         (bn2): BatchNormAct2d(
#           1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1968, 82, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(82, 1968, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1968, 328, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           328, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#   )
#   (conv_head): Conv2d(328, 2152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNormAct2d(
#     2152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (classifier): Linear(in_features=2152, out_features=18, bias=True)
# )

# %%
print(summary(model,torch.Tensor(2,3,224,224).to(device)))
# Out:
# ---------------------------------------------------------------------------------
#               Layer (type)          Output Shape         Param #     Tr. Param #
# =================================================================================
#                   Conv2d-1     [2, 32, 112, 112]             864             864
#           BatchNormAct2d-2     [2, 32, 112, 112]              64              64
#             EdgeResidual-3     [2, 32, 112, 112]          10,368          10,368
#             EdgeResidual-4     [2, 32, 112, 112]          10,368          10,368
#             EdgeResidual-5     [2, 32, 112, 112]          10,368          10,368
#             EdgeResidual-6       [2, 56, 56, 56]          44,400          44,400
#             EdgeResidual-7       [2, 56, 56, 56]         126,000         126,000
#             EdgeResidual-8       [2, 56, 56, 56]         126,000         126,000
#             EdgeResidual-9       [2, 56, 56, 56]         126,000         126,000
#            EdgeResidual-10       [2, 56, 56, 56]         126,000         126,000
#            EdgeResidual-11       [2, 80, 28, 28]         131,424         131,424
#            EdgeResidual-12       [2, 80, 28, 28]         256,800         256,800
#            EdgeResidual-13       [2, 80, 28, 28]         256,800         256,800
#            EdgeResidual-14       [2, 80, 28, 28]         256,800         256,800
#            EdgeResidual-15       [2, 80, 28, 28]         256,800         256,800
#        InvertedResidual-16      [2, 152, 14, 14]          91,844          91,844
#        InvertedResidual-17      [2, 152, 14, 14]         239,894         239,894
#        InvertedResidual-18      [2, 152, 14, 14]         239,894         239,894
#        InvertedResidual-19      [2, 152, 14, 14]         239,894         239,894
#        InvertedResidual-20      [2, 152, 14, 14]         239,894         239,894
#        InvertedResidual-21      [2, 152, 14, 14]         239,894         239,894
#        InvertedResidual-22      [2, 152, 14, 14]         239,894         239,894
#        InvertedResidual-23      [2, 152, 14, 14]         239,894         239,894
#        InvertedResidual-24      [2, 192, 14, 14]         396,230         396,230
#        InvertedResidual-25      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-26      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-27      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-28      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-29      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-30      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-31      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-32      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-33      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-34      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-35      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-36      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-37      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-38      [2, 192, 14, 14]         569,520         569,520
#        InvertedResidual-39        [2, 328, 7, 7]         726,464         726,464
#        InvertedResidual-40        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-41        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-42        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-43        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-44        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-45        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-46        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-47        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-48        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-49        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-50        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-51        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-52        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-53        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-54        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-55        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-56        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-57        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-58        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-59        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-60        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-61        [2, 328, 7, 7]       1,642,050       1,642,050
#        InvertedResidual-62        [2, 328, 7, 7]       1,642,050       1,642,050
#                  Conv2d-63       [2, 2152, 7, 7]         705,856         705,856
#          BatchNormAct2d-64       [2, 2152, 7, 7]           4,304           4,304
#    SelectAdaptivePool2d-65             [2, 2152]               0               0
#                  Linear-66               [2, 18]          38,754          38,754
# =================================================================================
# Total params: 51,122,196
# Trainable params: 51,122,196
# Non-trainable params: 0
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## Loss function

# %%
class FocalLoss(nn.Module):
    def __init__(self, weight=None,
                 gamma=2., reduction='mean'):
        nn.Module.__init__(self)
        self.weight = weight
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, input_tensor, target_tensor):
        log_prob = F.log_softmax(input_tensor, dim=-1)
        prob = torch.exp(log_prob)
        return F.nll_loss(
            ((1 - prob) ** self.gamma) * log_prob,
            target_tensor,
            weight=self.weight,
            reduction=self.reduction
        )

class F1Loss(nn.Module):
    def __init__(self, classes=18, epsilon=1e-7):
        super().__init__()
        self.classes = classes
        self.epsilon = epsilon

    def forward(self, y_pred, y_true):
        assert y_pred.ndim == 2
        assert y_true.ndim == 1
        y_true = F.one_hot(y_true, self.classes).to(torch.float32)
        y_pred = F.softmax(y_pred, dim=1)

        tp = (y_true * y_pred).sum(dim=0).to(torch.float32)
        tn = ((1 - y_true) * (1 - y_pred)).sum(dim=0).to(torch.float32)
        fp = ((1 - y_true) * y_pred).sum(dim=0).to(torch.float32)
        fn = (y_true * (1 - y_pred)).sum(dim=0).to(torch.float32)

        precision = tp / (tp + fp + self.epsilon)
        recall = tp / (tp + fn + self.epsilon)

        f1 = 2 * (precision * recall) / (precision + recall + self.epsilon)
        f1 = f1.clamp(min=self.epsilon, max=1 - self.epsilon)
        return 1 - f1.mean()

# %%
if loss_function_name == 'CrossEntropyLoss':
    criterion = nn.CrossEntropyLoss()
elif loss_function_name == 'FocalLoss':
    criterion = FocalLoss()
elif loss_function_name == 'F1Loss':
    criterion = F1Loss(classes=num_labels)
else:
    raise ValueError(f'not implement Loss function : {loss_function_name}')

# %% [markdown]
# ## Optimizer

# %%
# if you param freeze, not update during training
optimizer = None
if optimizer_name == 'AdamW':
    optimizer = AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=lr, weight_decay=weight_decay) # 0.09 
else:
    raise ValueError(f'not implement Optimizer : {optimizer_name}')

# %% [markdown]
# ## Scheduler

# %%
scheduler = None

if scheduler_name == 'ReduceLROnPlateau':
    ## during 5epochs, valid loss decrease 1e-3↓, lr update lr*0.5
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, threshold=1e-3) ## 정리
elif scheduler_name == 'CosineAnnealingWarmRestarts':
    scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-4)

assert scheduler != None , 'sheduler is None'

# %% [markdown]
# ## Train

# %%
best_val_acc = 0
best_val_f1 = 0
best_val_loss = np.Inf
best_kappa_val = 0

list_total_preds = [] # for analysis
list_total_labels = [] # for analysis

start=time.process_time()

for epoch in range(epochs):
    model.train()

    epoch_loss = 0
    epoch_preds = []
    epoch_labels = []

    iter_preds = []
    iter_labels = []

    for idx, train_batch in enumerate(train_loader):
        b_imgs, b_labels = train_batch # batch imgs and batch labels
        b_imgs = b_imgs.to(device)
        b_labels = b_labels.to(device)

        b_logits = model(b_imgs)
        b_loss = criterion(b_logits, b_labels)
        b_preds = torch.argmax(b_logits, dim=-1)

        optimizer.zero_grad()
        b_loss.backward()
        optimizer.step()

        epoch_loss += b_loss.item()
        epoch_preds += b_preds.detach().cpu().numpy().tolist()
        epoch_labels += b_labels.detach().cpu().numpy().tolist()

        # print interval batch
        if(idx+1) % print_interval == 0:
            current_loss = epoch_loss / (idx+1) # / batch
            correct_list = [i==j for i,j in zip(epoch_preds, epoch_labels)]
            current_acc = sum(correct_list) / len(correct_list)
            custom_sample_weight = [reversed_cls_prob[label] for label in epoch_labels] ## add this line
            epoch_train_f1 = f1_score(epoch_labels, epoch_preds, average='weighted', sample_weight=custom_sample_weight)
            train_kappa = cohen_kappa_score(epoch_labels,epoch_preds)
            print(
                    f"Epoch[{epoch+1}/{epochs}]({idx + 1}/{len(train_loader)}) || "
                    f"training loss {current_loss:2.4f} || training acc {current_acc:4.2%} || train f1 {epoch_train_f1:2.4f} || "
                    f"lr {optimizer.param_groups[0]['lr']:.5f}"
                )
    
    scheduler.step()
    
    with torch.no_grad():
        print("    Calculating validation results...")
        model.eval()

        val_loss = []
        val_acc = []

        val_preds = [] 
        val_labels = []

        for idx, val_batch in enumerate(val_loader):
            imgs, labels = val_batch
            imgs = imgs.to(device)
            labels = labels.to(device)

            logits = model(imgs)
            b_loss = criterion(logits, labels).item()
            
            preds = torch.argmax(logits, dim=-1)

            correct_num = (labels == preds).sum().item()

            val_loss.append(b_loss)
            val_acc.append(correct_num)

            val_preds += preds.detach().cpu().numpy().tolist()
            val_labels += labels.detach().cpu().numpy().tolist()

            

        epoch_val_loss =  np.sum(val_loss)/len(val_loader)
        epoch_val_acc = np.sum(val_acc)/len(val_dset)
        custom_sample_weight = [reversed_cls_prob[label] for label in val_labels] ## add this line
        epoch_val_f1 = f1_score(val_labels, val_preds, average='weighted', sample_weight=custom_sample_weight)
        kappa = cohen_kappa_score(val_labels, val_preds)
        best_val_loss = min(best_val_loss, epoch_val_loss)

        if epoch_val_f1 > best_val_f1:
                print(f"  New best model for val f1 : {epoch_val_f1:2.4f}! saving the best model..")
                best_val_f1 = epoch_val_f1
                torch.save(model.state_dict(), f"{save_dir}/best.pth")
                best_kappa_val = kappa
                list_total_preds = val_preds # if best score val-set, assign pred result to list_total_preds
                list_total_labels = val_labels # if best score val-set, assign pred result to list_total_preds
                best_val_acc = epoch_val_acc
                
        torch.save(model.state_dict(), f'{save_dir}/last.pth')
        print(
                f"    [{epoch+1} epoch Val] f1:{epoch_val_f1:2.4f}, loss:{epoch_val_loss:2.4f}, acc:{epoch_val_acc:4.2%} || "
                f"best f1:{best_val_f1:2.4f}, best loss:{best_val_loss:2.4f}, best state acc:{best_val_acc:4.2%}"
            )
        print(f"    Generalization gap => f1 : {epoch_train_f1-best_val_f1:2.4f}, current loss : {current_loss-epoch_val_loss:2.4f}")
    print()
end = time.process_time()
# Out:
# Epoch[1/20](394/473) || training loss 0.4220 || training acc 86.18% || train f1 0.7217 || lr 0.00030
#     Calculating validation results...
#   New best model for val f1 : 0.7856! saving the best model..
#     [1 epoch Val] f1:0.7856, loss:0.6332, acc:82.14% || best f1:0.7856, best loss:0.6332, best state acc:82.14%
#     Generalization gap => f1 : -0.0639, current loss : -0.2112
#
# Epoch[2/20](394/473) || training loss 0.0841 || training acc 97.20% || train f1 0.9450 || lr 0.00028
#     Calculating validation results...
#   New best model for val f1 : 0.8232! saving the best model..
#     [2 epoch Val] f1:0.8232, loss:0.5321, acc:87.62% || best f1:0.8232, best loss:0.5321, best state acc:87.62%
#     Generalization gap => f1 : 0.1218, current loss : -0.4480
#
# Epoch[3/20](394/473) || training loss 0.0422 || training acc 98.61% || train f1 0.9686 || lr 0.00023
#     Calculating validation results...
#   New best model for val f1 : 0.8367! saving the best model..
#     [3 epoch Val] f1:0.8367, loss:0.6091, acc:88.60% || best f1:0.8367, best loss:0.5321, best state acc:88.60%
#     Generalization gap => f1 : 0.1320, current loss : -0.5669
#
# Epoch[4/20](394/473) || training loss 0.0193 || training acc 99.44% || train f1 0.9899 || lr 0.00017
#     Calculating validation results...
#   New best model for val f1 : 0.8713! saving the best model..
#     [4 epoch Val] f1:0.8713, loss:0.5941, acc:89.87% || best f1:0.8713, best loss:0.5321, best state acc:89.87%
#     Generalization gap => f1 : 0.1186, current loss : -0.5748
#
# Epoch[5/20](394/473) || training loss 0.0071 || training acc 99.78% || train f1 0.9966 || lr 0.00012
#     Calculating validation results...
#     [5 epoch Val] f1:0.8665, loss:0.7316, acc:88.10% || best f1:0.8713, best loss:0.5321, best state acc:89.87%
#     Generalization gap => f1 : 0.1253, current loss : -0.7245
#
# Epoch[6/20](394/473) || training loss 0.0990 || training acc 96.99% || train f1 0.9458 || lr 0.00030
#     Calculating validation results...
#     [6 epoch Val] f1:0.8357, loss:0.6229, acc:88.84% || best f1:0.8713, best loss:0.5321, best state acc:89.87%
#     Generalization gap => f1 : 0.0745, current loss : -0.5239
#
# Epoch[7/20](394/473) || training loss 0.0561 || training acc 98.03% || train f1 0.9653 || lr 0.00028
#     Calculating validation results...
#     [7 epoch Val] f1:0.8277, loss:0.6559, acc:87.25% || best f1:0.8713, best loss:0.5321, best state acc:89.87%
#     Generalization gap => f1 : 0.0940, current loss : -0.5998
#
# Epoch[8/20](394/473) || training loss 0.0209 || training acc 99.36% || train f1 0.9862 || lr 0.00023
#     Calculating validation results...
#     [8 epoch Val] f1:0.8219, loss:0.8382, acc:85.58% || best f1:0.8713, best loss:0.5321, best state acc:89.87%
#     Generalization gap => f1 : 0.1149, current loss : -0.8173
#
# Epoch[9/20](394/473) || training loss 0.0105 || training acc 99.74% || train f1 0.9954 || lr 0.00017
#     Calculating validation results...
#     [9 epoch Val] f1:0.8519, loss:0.7897, acc:87.80% || best f1:0.8713, best loss:0.5321, best state acc:89.87%
#     Generalization gap => f1 : 0.1241, current loss : -0.7792
#
# Epoch[10/20](394/473) || training loss 0.0057 || training acc 99.80% || train f1 0.9959 || lr 0.00012
#     Calculating validation results...
#     [10 epoch Val] f1:0.8655, loss:0.7568, acc:88.44% || best f1:0.8713, best loss:0.5321, best state acc:89.87%
#     Generalization gap => f1 : 0.1246, current loss : -0.7511
#
# Epoch[11/20](394/473) || training loss 0.0671 || training acc 98.06% || train f1 0.9703 || lr 0.00030
#     Calculating validation results...
#     [11 epoch Val] f1:0.8218, loss:0.9819, acc:82.38% || best f1:0.8713, best loss:0.5321, best state acc:89.87%
#     Generalization gap => f1 : 0.0990, current loss : -0.9148
#
# Epoch[12/20](394/473) || training loss 0.0412 || training acc 98.72% || train f1 0.9726 || lr 0.00028
#     Calculating validation results...
#     [12 epoch Val] f1:0.7823, loss:0.7823, acc:84.71% || best f1:0.8713, best loss:0.5321, best state acc:89.87%
#     Generalization gap => f1 : 0.1013, current loss : -0.7411
#
# Epoch[13/20](394/473) || training loss 0.0127 || training acc 99.56% || train f1 0.9917 || lr 0.00023
#     Calculating validation results...
#     [13 epoch Val] f1:0.8486, loss:0.6896, acc:87.62% || best f1:0.8713, best loss:0.5321, best state acc:89.87%
#     Generalization gap => f1 : 0.1204, current loss : -0.6768
#
# Epoch[14/20](394/473) || training loss 0.0046 || training acc 99.87% || train f1 0.9976 || lr 0.00017
#     Calculating validation results...
#   New best model for val f1 : 0.8876! saving the best model..
#     [14 epoch Val] f1:0.8876, loss:0.5727, acc:91.90% || best f1:0.8876, best loss:0.5321, best state acc:91.90%
#     Generalization gap => f1 : 0.1101, current loss : -0.5681
#
# Epoch[15/20](394/473) || training loss 0.0065 || training acc 99.84% || train f1 0.9978 || lr 0.00012
#     Calculating validation results...
#     [15 epoch Val] f1:0.8687, loss:0.5911, acc:90.19% || best f1:0.8876, best loss:0.5321, best state acc:91.90%
#     Generalization gap => f1 : 0.1103, current loss : -0.5846
#
# Epoch[16/20](394/473) || training loss 0.0557 || training acc 98.24% || train f1 0.9676 || lr 0.00030
#     Calculating validation results...
#     [16 epoch Val] f1:0.8386, loss:0.5350, acc:89.07% || best f1:0.8876, best loss:0.5321, best state acc:91.90%
#     Generalization gap => f1 : 0.0800, current loss : -0.4794
#
# Epoch[17/20](394/473) || training loss 0.0308 || training acc 99.06% || train f1 0.9842 || lr 0.00028
#     Calculating validation results...
#     [17 epoch Val] f1:0.8772, loss:0.5807, acc:90.00% || best f1:0.8876, best loss:0.5321, best state acc:91.90%
#     Generalization gap => f1 : 0.0966, current loss : -0.5499
#
# Epoch[18/20](394/473) || training loss 0.0069 || training acc 99.76% || train f1 0.9958 || lr 0.00023
#     Calculating validation results...
#     [18 epoch Val] f1:0.8300, loss:0.7655, acc:86.80% || best f1:0.8876, best loss:0.5321, best state acc:91.90%
#     Generalization gap => f1 : 0.1082, current loss : -0.7586
#
# Epoch[19/20](394/473) || training loss 0.0028 || training acc 99.91% || train f1 0.9991 || lr 0.00017
#     Calculating validation results...
#     [19 epoch Val] f1:0.8214, loss:0.9288, acc:84.55% || best f1:0.8876, best loss:0.5321, best state acc:91.90%
#     Generalization gap => f1 : 0.1115, current loss : -0.9260
#
# Epoch[20/20](394/473) || training loss 0.0019 || training acc 99.97% || train f1 0.9998 || lr 0.00012
#     Calculating validation results...
#     [20 epoch Val] f1:0.8614, loss:0.7451, acc:88.76% || best f1:0.8876, best loss:0.5321, best state acc:91.90%
#     Generalization gap => f1 : 0.1122, current loss : -0.7432

# %% [markdown]
# ```
# weighted f1
# Epoch[20/20](394/473) || training loss 0.0040 || training acc 99.89% || train f1 0.9988 || lr 0.00012
#     Calculating validation results...
#   New best model for val f1 : 0.9929! saving the best model..
#     [20 epoch Val] f1:0.9929, loss:0.0222, acc:99.55% || best f1:0.9929, best loss:0.0222, best state acc:99.55%
#     Generalization gap => f1 : 0.0059, current loss : -0.0181
# ```

# %% [markdown]
# ```
# people split during this time, model memory people
# if my hypothesis is right, f1 score will be 0.8 under
# ```

# %% [markdown]
# ```
# Epoch[20/20](394/473) || training loss 0.0019 || training acc 99.97% || train f1 0.9998 || lr 0.00012
#     Calculating validation results...
#     [20 epoch Val] f1:0.8614, loss:0.7451, acc:88.76% || best f1:0.8876, best loss:0.5321, best state acc:91.90%
#     Generalization gap => f1 : 0.1122, current loss : -0.7432
# ```

# %%
print("Time elapsed: ", timedelta(seconds=end-start))
# Out:
# Time elapsed:  1:19:19.799375

# %% [markdown]
# ## Error Analysis

# %%
df_diff = pd.DataFrame()
df_diff['labels'] = list_total_labels
df_diff['preds'] = list_total_preds
df_diff.to_csv(f'{save_dir}/diff.csv')

# %%
## label to sentence
def get_sentence(code):
    codebook = ['Wear,male,junior', # 0
                'Wear,male,middle', # 1
                'Wear,male,senior', # 2
                'Wear,female,junior', # 3
                'Wear,female,middle', # 4
                'Wear,female,senior', # 5
                'Incorrect,male,junior', # 6
                'Incorrect,male,middle', # 7
                'Incorrect,male,senior', # 8
                'Incorrect,female,junior', # 9
                'Incorrect,female,middle', # 10
                'Incorrect,female,senior', # 11
                'Not Wear,male,junior', # 12
                'Not Wear,male,middle', # 13
                'Not Wear,male,senior', # 14
                'Not Wear,female,junior', # 15
                'Not Wear,female,middle', # 16
                'Not Wear,female,senior'] # 17
    return codebook[code]

# age to sentence
def get_age_category(num):
    category = None
    if num>=60:
        category = 'senior'
    elif 30<=num<60:
        category = 'middle'
    else:
        category = 'junior'
    return category

# %%
list_wear_labels = []
list_gender_labels = []
list_age_labels = []

list_wear_preds = []
list_gender_preds = []
list_age_preds = []

for label in df_diff['labels']:
    row = get_sentence(label).split(',')
    list_wear_labels.append(row[0])
    list_gender_labels.append(row[1])
    list_age_labels.append(row[2])

for label in df_diff['preds']:
    row = get_sentence(label).split(',')
    list_wear_preds.append(row[0])
    list_gender_preds.append(row[1])
    list_age_preds.append(row[2])

# %%
list_cause = []
for row in zip(list_wear_labels, list_wear_preds, list_gender_labels, list_gender_preds, list_age_labels, list_age_preds):
    sentence = []
    if row[0] != row[1]:
        sentence.append(f'mask   : {row[0]} → {row[1]}')
    if row[2] != row[3]:
        sentence.append(f'gender : {row[2]} → {row[3]}')
    if row[4] != row[5]:
        sentence.append(f'age    : {row[4]} → {row[5]}')
    
    if len(sentence) == 0:
        sentence = "all correct"
    elif len(sentence) == 1:
        sentence = sentence[0]
    else: # len(sentence) == 2
        sentence = ','.join(sentence)
    list_cause.append(sentence)

# %%
l = pd.Series(list_cause)
l.value_counts().sort_values(ascending = False)
# Out:
# all correct                                        3474
# age    : junior → middle                             83
# age    : middle → junior                             76
# gender : female → male                               61
# age    : senior → middle                             42
# gender : male → female                               33
# mask   : Incorrect → Not Wear                         3
# mask   : Incorrect → Wear                             3
# mask   : Wear → Incorrect                             2
# age    : middle → senior                              1
# gender : male → female,age    : junior → middle       1
# gender : female → male,age    : middle → junior       1
# dtype: int64

# %% [markdown]
# ```
# normal f1 checkpoint
# all correct                      3763
# mask   : Incorrect → Wear           6
# age    : middle → junior            6
# age    : middle → senior            2
# gender : male → female              1
# mask   : Incorrect → Not Wear       1
# mask   : Not Wear → Incorrect       1
# dtype: int64
# ```

# %% [markdown]
# ```
# people split during this time, model memory people
# if my hypothesis is right, f1 score will be 0.8 under
# ```

# %%
df_diff['cause'] = list_cause
df_diff.to_csv(f'{save_dir}/analysis.csv')

# %% [markdown]
# ## inference

# %% [markdown]
# ## inference config

# %%
model_name = 'efficientnetv2_rw_m'
check_point_dir_name = 'baseline2'
save_file_path = f'./checkpoints/{check_point_dir_name}/best.pth'
test_dir = './dataset/eval/images/'
test_csv_path = './dataset/eval/info.csv'

test_b_size = 500
num_labels = 18
sumbission_csv_name = 'result'

# %% [markdown]
# ## checkpoint model load

# %%
model = timm.create_model(model_name=model_name, pretrained=False, num_classes=num_labels)
model.to(device)
model.load_state_dict(torch.load(save_file_path))
model = torch.nn.DataParallel(model)

# %% [markdown]
# ## test dataset

# %%
class CustomTestDataset(Dataset):
    def __init__(self, img_paths:list, transforms=None):
        self.img_paths = img_paths
        self.transforms = transforms
        assert self.transforms is not None, 'you must use transforms in Testset'

    def __getitem__(self, index):
        img = Image.open(self.img_paths[index])
        img = np.array(img)
        img = self.transforms(image=img)["image"]
        return img

    def __len__(self):
        return len(self.img_paths)

# %%
test_transforms = A.Compose([A.Resize(224, 224),
                             A.Normalize(mean=(0.560,0.524,0.501), std=(0.233,0.243,0.246)),
                             ToTensorV2()])

# %%
info = pd.read_csv(test_csv_path)
test_imgs_path = [os.path.join(test_dir, img_id) for img_id in info.ImageID]

# %%
test_dset = CustomTestDataset(test_imgs_path, test_transforms)

# %%
test_loader = DataLoader(
        test_dset,
        batch_size=test_b_size,
        num_workers=multiprocessing.cpu_count() // 2,
        shuffle=False,
        pin_memory=use_cuda,
        drop_last=False,
    )

# %%
test_preds = []
with torch.no_grad():
        for idx, images in enumerate(test_loader):
            images = images.to(device)
            pred = model(images)
            pred = pred.argmax(dim=-1)
            test_preds.extend(pred.cpu().numpy().tolist())

info['ans'] = test_preds
save_path = os.path.join(save_dir, f'{sumbission_csv_name}.csv')
info.to_csv(save_path, index=False)
print(f"Inference Done! Inference result saved at {save_path}")

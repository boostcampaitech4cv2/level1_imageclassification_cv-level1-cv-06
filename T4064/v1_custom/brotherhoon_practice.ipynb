# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import os
from pathlib import Path
import numpy as np
import torch
import timm

# %%
current_path = Path(os.getcwd())
file_path = os.path.join(current_path.parent,'dataset','train','custom_train.csv')
img_info = pd.read_csv(file_path)

# %%
current_path.parent.parent
# Out:
# PosixPath('/opt/ml/repo/level1_imageclassification_cv-level1-cv-06')

# %%
img_info
# Out:
#        Unnamed: 0                                               path  \
# 0               0  /opt/ml/repo/level1_imageclassification_cv-lev...
# 1               1  /opt/ml/repo/level1_imageclassification_cv-lev...
# 2               2  /opt/ml/repo/level1_imageclassification_cv-lev...
# 3               3  /opt/ml/repo/level1_imageclassification_cv-lev...
# 4               4  /opt/ml/repo/level1_imageclassification_cv-lev...
# ...           ...                                                ...
# 18895       18895  /opt/ml/repo/level1_imageclassification_cv-lev...
# 18896       18896  /opt/ml/repo/level1_imageclassification_cv-lev...
# 18897       18897  /opt/ml/repo/level1_imageclassification_cv-lev...
# 18898       18898  /opt/ml/repo/level1_imageclassification_cv-lev...
# 18899       18899  /opt/ml/repo/level1_imageclassification_cv-lev...
#
#       mask_state  age  gender  class
# 0           Wear   45  female      4
# 1       Not Wear   45  female     16
# ...

# %%
from dataset import CustomTrainDataset, CustomTestDataset
import albumentations as A
from albumentations import *
from albumentations.pytorch import ToTensorV2

train_transforms = A.Compose([A.Resize(height=224, width=224),
                              A.HorizontalFlip(p=0.5),
                              A.RandomBrightnessContrast(p=0.5),
                              A.GaussianBlur(p=0.5),
                              A.GridDistortion(p=0.5),
                              A.Rotate(limit=30, p=0.5),
                              A.Normalize(mean=(0.56019358,0.52410121,0.501457),
                                          std=(0.23318603,0.24300033,0.24567522)),
                              ToTensorV2()])

train_dset = CustomTrainDataset(img_paths=img_info['path'],labels=img_info['class'], transforms=train_transforms)
test_dset = CustomTestDataset(img_paths=img_info['path'], transforms=train_transforms)

# %%
img, label = train_dset[1]
torch.tensor(label).size()
# Out:
# torch.Size([])

# %%
img_info['path'], img_info['class'], img_info['class']

train_paths, valid_paths, train_labels, valid_labels = train_test_split(img_info['path'], img_info['class'],
                                                                        train_size = 0.7,
                                                                        shuffle = True,
                                                                        random_state = 42,
                                                                        stratify=img_info['class'])

# %%
s = pd.Series(['a','b','c','a'])
pd.get_dummies(s).to_numpy()
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1],
#        [1, 0, 0]], dtype=uint8)

# %%
d = np.ndarray(['a','b','c','a'])
pd.get_dummies(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 d = np.ndarray(['a','b','c','a'])
#       2 pd.get_dummies(d)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
train_paths.to_numpy()
# Out:
# array(['/opt/ml/repo/level1_imageclassification_cv-level1-cv-06/T4064/dataset/train/images/004413_male_Asian_18/mask5.jpg',
#        '/opt/ml/repo/level1_imageclassification_cv-level1-cv-06/T4064/dataset/train/images/000071_female_Asian_56/normal.jpg',
#        '/opt/ml/repo/level1_imageclassification_cv-level1-cv-06/T4064/dataset/train/images/004441_female_Asian_55/mask4.jpg',
#        ...,
#        '/opt/ml/repo/level1_imageclassification_cv-level1-cv-06/T4064/dataset/train/images/003560_male_Asian_55/incorrect_mask.jpg',
#        '/opt/ml/repo/level1_imageclassification_cv-level1-cv-06/T4064/dataset/train/images/001352_female_Asian_18/mask5.jpg',
#        '/opt/ml/repo/level1_imageclassification_cv-level1-cv-06/T4064/dataset/train/images/005274_male_Asian_20/mask2.jpg'],
#       dtype=object)

# %%
for i in train_paths:
    print(i)
    break
# Out:
# /opt/ml/repo/level1_imageclassification_cv-level1-cv-06/T4064/dataset/train/images/004413_male_Asian_18/mask5.jpg

# %%
import timm
for model in timm.list_models():
    print(model)
# Out:
# adv_inception_v3
# bat_resnext26ts
# beit_base_patch16_224
# beit_base_patch16_224_in22k
# beit_base_patch16_384
# beit_large_patch16_224
# beit_large_patch16_224_in22k
# beit_large_patch16_384
# beit_large_patch16_512
# beitv2_base_patch16_224
# beitv2_base_patch16_224_in22k
# beitv2_large_patch16_224
# beitv2_large_patch16_224_in22k
# botnet26t_256
# botnet50ts_256
# cait_m36_384
# cait_m48_448
# cait_s24_224
# cait_s24_384
# cait_s36_384
# cait_xs24_384
# cait_xxs24_224
# cait_xxs24_384
# cait_xxs36_224
# cait_xxs36_384
# coat_lite_mini
# coat_lite_small
# coat_lite_tiny
# coat_mini
# coat_tiny
# coatnet_0_224
# coatnet_0_rw_224
# coatnet_1_224
# coatnet_1_rw_224
# coatnet_2_224
# coatnet_2_rw_224
# coatnet_3_224
# coatnet_3_rw_224
# coatnet_4_224
# coatnet_5_224
# coatnet_bn_0_rw_224
# coatnet_nano_cc_224
# coatnet_nano_rw_224
# coatnet_pico_rw_224
# coatnet_rmlp_0_rw_224
# coatnet_rmlp_1_rw_224
# coatnet_rmlp_2_rw_224
# coatnet_rmlp_3_rw_224
# coatnet_rmlp_nano_rw_224
# ...

# %%
def load_model(model_dir, name, model_name, n_classes, device):
    model_path = os.path.join(model_dir, name, 'best.pth')
    model = timm.create_model(model_name=model_name, 
                              num_classes=n_classes, 
                              pretrained=True)
    model.load_state_dict(torch.load(checkpoint_path=model_path, map_location=device))
    return model

# %%
def load_model(model_dir, checkpoint_name, model_name, n_classes, device):
    model_path = os.path.join(model_dir, checkpoint_name, 'best.pth')
    model = timm.create_model(model_name=model_name, 
                              num_classes=n_classes, 
                              pretrained=True)
    model.load_state_dict(torch.load(model_path, map_location=device))

    return model

# %%
model_dir = './T4064/checkpoints'
checkpoint_name = 'good_night'
model_name = 'efficientnet_b3_pruned'
n_classes = 18
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
model = load_model(model_dir,checkpoint_name,model_name,n_classes, device)
name_list = [k for k, v in model.named_parameters()]

# %%
name_list
# Out:
# ['conv_stem.weight',
#  'bn1.weight',
#  'bn1.bias',
#  'blocks.0.0.conv_dw.weight',
#  'blocks.0.0.bn1.weight',
#  'blocks.0.0.bn1.bias',
#  'blocks.0.0.se.conv_reduce.weight',
#  'blocks.0.0.se.conv_reduce.bias',
#  'blocks.0.0.se.conv_expand.weight',
#  'blocks.0.0.se.conv_expand.bias',
#  'blocks.0.0.conv_pw.weight',
#  'blocks.0.0.bn2.weight',
#  'blocks.0.0.bn2.bias',
#  'blocks.0.1.conv_dw.weight',
#  'blocks.0.1.bn1.weight',
#  'blocks.0.1.bn1.bias',
#  'blocks.0.1.se.conv_reduce.weight',
#  'blocks.0.1.se.conv_reduce.bias',
#  'blocks.0.1.se.conv_expand.weight',
#  'blocks.0.1.se.conv_expand.bias',
#  'blocks.0.1.conv_pw.weight',
#  'blocks.0.1.bn2.weight',
#  'blocks.0.1.bn2.bias',
#  'blocks.1.0.conv_pw.weight',
#  'blocks.1.0.bn1.weight',
#  'blocks.1.0.bn1.bias',
#  'blocks.1.0.conv_dw.weight',
#  'blocks.1.0.bn2.weight',
#  'blocks.1.0.bn2.bias',
#  'blocks.1.0.se.conv_reduce.weight',
#  'blocks.1.0.se.conv_reduce.bias',
#  'blocks.1.0.se.conv_expand.weight',
# ...

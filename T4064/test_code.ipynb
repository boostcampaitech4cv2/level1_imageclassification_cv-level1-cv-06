# %%
print('hello world!')
# Out:
# hello world!

# %%
import os
current_dir = os.getcwd()
path = os.path.join(current_dir, 'dataset/train/images/')

# %%
import glob

file_name = '._*'
file_path = path + file_name
[os.remove(f) for f in glob.glob(file_path)]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
current_dir
# Out:
# '/opt/ml/repo/level1_imageclassification_cv-level1-cv-06/T4064'

# %%
import os
current_dir = os.getcwd()
path = os.path.join(current_dir, 'dataset/eval/images/')

# %%
import glob

file_name = '._*'
file_path = path + file_name
[os.remove(f) for f in glob.glob(file_path)]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
file_path = os.path.join(current_dir, 'dataset/eval/images/')
len(os.listdir(file_path))
# Out:
# 12600

# %%
import pandas as pd

csv_file = pd.read_csv('dataset/eval/info.csv')
len(csv_file)
# Out:
# 12600

# %%
file_path = os.path.join(current_dir, 'dataset/train/images/')
len(os.listdir(file_path))
# Out:
# 2700

# %%
file_path
# Out:
# '/opt/ml/repo/level1_imageclassification_cv-level1-cv-06/T4064/dataset/train/images/'

# %%
import os

dir_path = file_path
for path, dirs, files in os.walk(dir_path):
    for file in files:
        file_path = os.path.join(path, file)
        if file.startswith('._'):
            os.remove(file_path)
